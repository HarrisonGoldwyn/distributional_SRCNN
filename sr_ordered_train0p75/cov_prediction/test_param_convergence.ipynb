# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
losses = np.load("/Users/hgoldwyn/Research/projects/SR_CNN/paper_repo/sr_ordered_train0p75/stage_2/output/parCov_fitting_fourier_allImages_mseStart_globalPrior_anal_empPriorStdOn4p5_test_param_fit_losses.npy")

# %%
plt.plot(losses.T)
# plt.yscale('log')
